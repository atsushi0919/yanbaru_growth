# %% [markdown]
# # HTMLのCanvasで図形を描く
#
# ---
#
# ## 目次
#
# 1. Canvasとは
# 2. コンテキストとは
# 3. サンプルコード紹介
# 4. まとめ
#
# ---
#
# ### 1. Canvasとは
#
# #### HTML5から追加されたHTMLの要素
#
# - CanvasAPIの技術仕様に沿ってJavaScript等から指示を与えることで「図形や文字を描画」することができる
# - HTMLでは `<canvas></canvas>` のように記述する
# - 図形や文字の変形や色やスタイルの変更を「動的」に扱うことが出来る
# - 「コンテキストオブジェクト(context object)」によって描画機能が提供される
# - 図形を表示するには、canvasタグをサポートしたブラウザが必要 (余程古くなければ大丈夫)
#
# ---
#
# ### 2. コンテキストとは
#
# - コンテキストとは、描画に関わる設定情報の状態（例えばペンの太さや色）
# - コンテキストオブジェクトとは、コンテキストが構造化されたオブジェクト
# - 「2Dのコンテキスト」と「3Dのコンテキスト」があり、総称して「描画コンテキスト」と呼ばれる
#
# #### CanvasRenderringContext2Dオブジェクト（2Dのコンテキスト）
#
# 参考: [株式会社リースエンタープライズ(Web制作会社HP)](https://wreath-ent.co.jp/)
#
# #### WebGLRenderingContextオブジェクト（3Dのコンテキスト）
#
# 参考: [ics.media(フロントエンジニアのための情報サイト)](https://ics.media/entry/2328/)
#
#
# ---
#
# ### 3. サンプルコード紹介
#
# 今回は、CanvasRenderringContext2Dオブジェクト（通称: Canvas2Dコンテキスト）を使用したアナログ時計の描画デモをご紹介します。
#
# Canvas2Dコンテキストの主なプロパティ
#
# | プロパティ | 説明 |
# | :---: | :---: |
# | context.strokeStyle | 線や輪郭の色 |
# | context.fillStyle | 塗りつぶしの色 |
# | context.lineWidth | 線の幅 |
# | context.shadowColor | 影の色 |
# | context.shadowBlur | 影のぼかし範囲 |
#
# 参考： [Canvasリファレンス](http://www.htmq.com/canvas/)
#
# ---
#
# #### アナログ時計サンプルコード
#
# - #### [HTML: clock.html](https://github.com/atsushi0919/yanbaru_growth/blob/main/yanbaru_growth_06_html/clock.html)
# - #### [JavaScript: script.js](https://github.com/atsushi0919/yanbaru_growth/blob/main/yanbaru_growth_06_html/script.js)
#
# ---
#
# ### 4. まとめ
#
# Canvas(API)を使うと、割と簡単にHTMLに図形やアニメーションを表示することが出来るので便利。今回紹介していないがペジェ曲線などにも対応しているので、しっかり覚えれば、かなり色々なことが出来そう。
# 今回の資料作成中にWebGLの3D描画デモを見てとても感動した。いつか3DGCを扱ってみたい！
